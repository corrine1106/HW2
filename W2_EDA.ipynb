# %% [markdown]
# <a href="https://colab.research.google.com/github/corrine1106/HW2/blob/main/W2_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/T大使/data3_project.csv')

# %%
df
# Out:
#             InvoiceNo StockCode  ... member_start_date  first_trans_date
# 0        PS5327001158      JA01  ...        2019-12-09        2018-06-24
# 1        PS5335020955      KG06  ...        2018-10-21        2018-10-21
# 2        PS5335020955     BJ102  ...        2018-10-21        2018-10-21
# 3        PS5335020955    JZA3G1  ...        2018-10-21        2018-10-21
# 4        PS5444006919     BJ103  ...        2018-12-04        2018-12-04
# ...               ...       ...  ...               ...               ...
# 1404430  PS5324024941      KQ02  ...        2010-03-15        2012-07-11
# 1404431  PS5219002027    GAXFG1  ...        2020-12-08        2020-11-26
# 1404432  PS5219002027    MAB2G1  ...        2020-12-08        2020-11-26
# 1404433  PS5219002027     WD096  ...        2020-12-08        2020-11-26
# 1404434  PS5219002028    GAXFG2  ...        2020-12-23        2020-12-10
#
# [1404435 rows x 10 columns]

# %%
# 1
df1 = df.loc[(df['InvoiceDate']<'2020-11-30') & (df['InvoiceDate']>'2020-11-01')]

# %%
df1
# Out:
#             InvoiceNo StockCode  ... member_start_date  first_trans_date
# 1285786  PS5234023583    MAB3G1  ...        2003-09-06        2012-07-21
# 1285787  PS5234023584     BJ102  ...        2003-09-06        2012-07-21
# 1285788  PS5234023585    JAF4G1  ...        2003-09-06        2012-07-21
# 1285789  PS5234023586    GAM1G3  ...        2003-09-06        2012-07-21
# 1285790  PS5160026637    JYA9G1  ...        2010-11-17        2012-09-24
# ...               ...       ...  ...               ...               ...
# 1340825  PS5324024608    JAF1G2  ...        2012-05-06        2012-08-26
# 1340826  PS5324024608    MAB6G2  ...        2012-05-06        2012-08-26
# 1340827  PS5324024609    JAG5G1  ...        2003-07-14        2012-09-06
# 1340828  PS5324024609    GAM1G2  ...        2003-07-14        2012-09-06
# 1340829  PS5324024609    MAB6G2  ...        2003-07-14        2012-09-06
#
# [55044 rows x 10 columns]

# %%
# 2
i = df1.loc[(df1.UnitPrice < 0) | ( df1.UnitPrice > 3000)].index
df1.drop(i, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1
# Out:
#             InvoiceNo StockCode  ... member_start_date  first_trans_date
# 1285787  PS5234023584     BJ102  ...        2003-09-06        2012-07-21
# 1285788  PS5234023585    JAF4G1  ...        2003-09-06        2012-07-21
# 1285789  PS5234023586    GAM1G3  ...        2003-09-06        2012-07-21
# 1285790  PS5160026637    JYA9G1  ...        2010-11-17        2012-09-24
# 1285791  PS5160026637    JYB1G1  ...        2010-11-17        2012-09-24
# ...               ...       ...  ...               ...               ...
# 1340823  PS5145024031      KV05  ...        2010-09-15        2012-09-06
# 1340824  PS5324024608    GAM1G2  ...        2012-05-06        2012-08-26
# 1340825  PS5324024608    JAF1G2  ...        2012-05-06        2012-08-26
# 1340827  PS5324024609    JAG5G1  ...        2003-07-14        2012-09-06
# 1340828  PS5324024609    GAM1G2  ...        2003-07-14        2012-09-06
#
# [44457 rows x 10 columns]

# %%
# 3
df2 = df1.loc[:,['CustomerID','StockCode','Description']]

# %%
df2
# Out:
#            CustomerID StockCode        Description
# 1285787  9.100000e+12     BJ102       檸檬精油10ml MUI
# 1285788  9.100000e+12    JAF4G1        蘆薈舒緩凝膠150ml
# 1285789  9.100000e+12    GAM1G3  茶樹75%酒精乾洗手噴霧100ml
# 1285790  9.100001e+12    JYA9G1        天竺葵芳香精油10ml
# 1285791  9.100001e+12    JYB1G1        藍膠尤加利精油15ml
# ...               ...       ...                ...
# 1340823  9.100001e+12      KV05     超防禦UV潤色妝前乳30ml
# 1340824  9.100001e+12    GAM1G2   茶樹75%酒精乾洗手噴霧55ml
# 1340825  9.100001e+12    JAF1G2   私密御守清潔露200ml-微涼感
# 1340827  9.100000e+12    JAG5G1         水光肌能乳液80ml
# 1340828  9.100000e+12    GAM1G2   茶樹75%酒精乾洗手噴霧55ml
#
# [44457 rows x 3 columns]
